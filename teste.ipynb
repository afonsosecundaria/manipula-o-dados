# %% [markdown]
# Este é o Arquivo que uso para testar os códigos

# %%
# Importando a Biblioteca
import pandas as pd

# %%
# Puxando o arquivo de dados e mostrando ele na tela
vendas_db = pd.read_excel('C:/Users/andre/Desktop/pandas/manipula-o-dados/Bancosdedados/Vendas.xlsx')
display(vendas_db)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final
# 0               1             358          358
# ...

# %%
# Criando um backup para o nosso banco de dados
backup_vendas = vendas_db.copy()

# %%
# Assim podemos mexer o quanto quiser na nossa tabela tendo uma cópia dela original
vendas_db = vendas_db.loc[vendas_db['Produto'] == 'Camiseta']
display(backup_vendas.head(10))
display(vendas_db.head(10))
# Out:
#    Código Venda       Data                     ID Loja  \
# 0             1 2019-01-01          Iguatemi Esplanada
# 1             1 2019-01-01          Iguatemi Esplanada
# 2             1 2019-01-01          Iguatemi Esplanada
# 3             2 2019-01-02              Norte Shopping
# 4             2 2019-01-02              Norte Shopping
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza
# 6             5 2019-01-02              Shopping Barra
# 7             6 2019-01-02         Shopping Ibirapuera
# 8             7 2019-01-02              Norte Shopping
# 9             7 2019-01-02              Norte Shopping
#
#                   Produto  Quantidade  Valor Unitário  Valor Final
# 0          Sapato Estampa           1             358          358
# 1                Camiseta           2             180          360
# 2           Sapato Xadrez           1             368          368
# 3                 Relógio           3             200          600
# ...

# %%
# .head mostra as 5 ou mais linhas da tabela
vendas_db.head(10)
# Out:
#    Código Venda       Data                     ID Loja  \
# 0             1 2019-01-01          Iguatemi Esplanada
# 1             1 2019-01-01          Iguatemi Esplanada
# 2             1 2019-01-01          Iguatemi Esplanada
# 3             2 2019-01-02              Norte Shopping
# 4             2 2019-01-02              Norte Shopping
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza
# 6             5 2019-01-02              Shopping Barra
# 7             6 2019-01-02         Shopping Ibirapuera
# 8             7 2019-01-02              Norte Shopping
# 9             7 2019-01-02              Norte Shopping
#
#                   Produto  Quantidade  Valor Unitário  Valor Final
# 0          Sapato Estampa           1             358          358
# 1                Camiseta           2             180          360
# 2           Sapato Xadrez           1             368          368
# 3                 Relógio           3             200          600
# ...

# %%
# Mostrando somente as linhas e colunas que desejo
somentenorteshopping = vendas_db.loc[vendas_db['ID Loja'] == 'Norte Shopping', ['ID Loja', 'Produto', 'Valor Final']]
display(somentenorteshopping)
# Out:
#               ID Loja                 Produto  Valor Final
# 3      Norte Shopping                 Relógio          600
# 4      Norte Shopping            Chinelo Liso           71
# 8      Norte Shopping  Camisa Gola V Listrado          116
# 9      Norte Shopping             Camisa Liso          105
# 100    Norte Shopping            Cueca Xadrez          300
# ...               ...                     ...          ...
# 93716  Norte Shopping             Polo Xadrez          142
# 93754  Norte Shopping              Calça Liso          190
# 93755  Norte Shopping          Casaco Estampa          512
# 93756  Norte Shopping                   Gorro          160
# 93852  Norte Shopping           Bermuda Linho          195
#
# [3924 rows x 3 columns]

# %%
# Criando uma coluna a partir de uma existente
vendas_db['Comissão'] = vendas_db['Valor Final'] * 0.5
display(vendas_db)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final  Comissão
# 0               1             358          358     179.0
# ...

# %%
# Criando uma coluna e preenchendo ela com um valor fixo
vendas_db['Imposto'] = 0 
display(vendas_db)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Criando uma coluna e preenchendo ela com um valor fixo
# ----> 2 vendas_db['Imposto'] = 0 * 0
#       3 display(vendas_db)
#
# TypeError: 'int' object does not support item assignment
